# %%
# !pwd

# %%
print("Hola!")
# Out:
# Hola!

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
x=5;y=20

# %%
print("y:%d" %(y))
# Out:
# y:20

# %%
print("A dios desde google Colab")
# Out:
# Hola desde google Colab
